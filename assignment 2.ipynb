# %%
#import the libraries 
import pandas as pd

# %%
df1 = pd.read_excel("amz_com-ecommerce_sample.xlsx")

# %%
df2 = pd.read_excel("flipkart_com-ecommerce_sample.xlsx")

# %%
df1.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df2.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df1.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
#drop the columns which are not useful
cols_not_used = ['uniq_id','crawl_timestamp', 'product_url','product_category_tree','product_rating','overall_rating','product_specifications', 'is_FK_Advantage_product','image','brand','product_specifications']

# %%
df1 = df1.drop(cols_not_used,axis='columns')

# %%
df1.head()
# Out:
#                             product_name               pid  retail_price  \
# 0    Alisha Solid Women's Cycling Shorts  SRTEH2FF9KEDEFGF           982
# 1    FabHomeDecor Fabric Double Sofa Bed  SBEEH3QGU7MFYJFY         32143
# 2                             AW Bellies  SHOEH4GRSUBJGZXE           991
# 3    Alisha Solid Women's Cycling Shorts  SRTEH2F6HUZMQ6SJ           694
# 4  Sicons All Purpose Arnica Dog Shampoo  PSOEH3ZYDMSYARJ5           208
#
#    discounted_price                                        description
# 0               438  Key Features of Alisha Solid Women's Cycling S...
# 1             29121  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2               551  Key Features of AW Bellies Sandals Wedges Heel...
# 3               325  Key Features of Alisha Solid Women's Cycling S...
# 4               258  Specifications of Sicons All Purpose Arnica Do...

# %%
#renaming the columns
df1.rename(columns= {'product_name' : "Product name in Amazon"}, inplace=True)
df1.rename(columns= {'retail_price' : "Retail Price in Amazon"}, inplace=True)
df1.rename(columns= {'discounted_price' : "Discounted Price in Amazon"}, inplace=True)

# %%
df2.rename(columns= {'product_name' : "Product name in Flipkart"}, inplace=True)
df2.rename(columns= {'retail_price' : "Retail Price in Flipkart"}, inplace=True)
df2.rename(columns= {'discounted_price' : "Discounted Price in Flipkart"}, inplace=True)

# %%
df = pd.concat([df1,df2],axis=1)
df.head()
# Out:
#                   Product name in Amazon               pid  \
# 0    Alisha Solid Women's Cycling Shorts  SRTEH2FF9KEDEFGF
# 1    FabHomeDecor Fabric Double Sofa Bed  SBEEH3QGU7MFYJFY
# 2                             AW Bellies  SHOEH4GRSUBJGZXE
# 3    Alisha Solid Women's Cycling Shorts  SRTEH2F6HUZMQ6SJ
# 4  Sicons All Purpose Arnica Dog Shampoo  PSOEH3ZYDMSYARJ5
#
#    Retail Price in Amazon  Discounted Price in Amazon  \
# 0                     982                         438
# 1                   32143                       29121
# 2                     991                         551
# 3                     694                         325
# 4                     208                         258
#
#                                          description  \
# 0  Key Features of Alisha Solid Women's Cycling S...
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2  Key Features of AW Bellies Sandals Wedges Heel...
# 3  Key Features of Alisha Solid Women's Cycling S...
# ...

# %%
new_df = df.drop(['description', 'pid'], axis='columns')

# %%
new_df.isnull().sum()
# Out:
# Product name in Amazon             0
# Retail Price in Amazon             0
# Discounted Price in Amazon         0
# uniq_id                            0
# crawl_timestamp                    0
# product_url                        0
# Product name in Flipkart           0
# product_category_tree              0
# Retail Price in Flipkart           0
# Discounted Price in Flipkart       0
# image                              3
# is_FK_Advantage_product            0
# product_rating                     0
# overall_rating                     0
# brand                           5864
# product_specifications            14
# dtype: int64

# %%
new_df.dropna(inplace=True)

# %%
new_df = new_df[new_df['Product name in Amazon'] == new_df['Product name in Flipkart']]

# %%
new_df.shape
# Out:
# (14122, 16)

# %%
new_df.describe()
# Out:
#        Retail Price in Amazon  Discounted Price in Amazon  \
# count            14122.000000                14122.000000
# mean              3613.568262                 2893.980952
# std               9254.360749                 8370.743216
# min                -20.000000                    0.000000
# 25%                686.000000                  416.000000
# 50%               1092.000000                  661.000000
# 75%               2186.000000                 1473.750000
# max             250483.000000               207175.000000
#
#        Retail Price in Flipkart  Discounted Price in Flipkart
# count              14122.000000                  14122.000000
# mean                3613.568262                   2893.980952
# std                 9254.360749                   8370.743216
# min                  -20.000000                      0.000000
# 25%                  686.000000                    416.000000
# 50%                 1092.000000                    661.000000
# ...

# %% [markdown]
# new_df contains matched product name final data

# %%
#saving the output file
file_name = 'assignment2_output.xlsx'
new_df.to_excel(file_name)
